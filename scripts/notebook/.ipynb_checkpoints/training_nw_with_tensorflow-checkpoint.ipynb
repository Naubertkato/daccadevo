# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)

from tensorflow.keras.layers import Dense
from tensorflow.keras import Model
from tensorflow.keras import layers
# Out:
# TensorFlow version: 2.5.0

# %%
import os
import sys
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from datetime import datetime

# %%
from pathlib import Path
current_dir = os.path.join(Path().resolve())
sys.path.append(str(current_dir) + '/../')

# %%
from ReservoirRun import Reservoir
from evolver import DaccadBioneatMut, DaccadBioneatMut_5
from qdpy.containers import *
from individual import *

# %% [markdown]
# ## Loading a dataset

# %%
myarray_np = np.loadtxt('../data/dataset_myarray_1.csv', delimiter=',')
mc_np = np.loadtxt('../data/dataset_mc_1.csv', delimiter=',')

# %%
myarray_np = np.concatenate([myarray_np, myarray_1_np])
mc_np = np.concatenate([mc_np, mc_1_np])

# %%
myarray_np.shape
# Out:
# (3276, 155)

# %%
# save as a npz file
np.save('../data/myarray_1', myarray_np)
np.save('../data/mc_1', mc_np)

# %% [markdown]
# ## Split into train data and test data as dataset

# %%
myarray_fullPath = os.path.abspath('./data/myarray_1.npy')
myarray_path = tf.keras.utils.get_file('myarray_1.npy', 'file://'+myarray_fullPath)
myarray_data = np.load(myarray_path)
#x_train, x_test = train_test_split(myarray_data, test_size=0.2)


mc_fullPath = os.path.abspath('./data/mc_1.npy')
mc_path = tf.keras.utils.get_file('mc_1.npy', 'file://'+mc_fullPath)
mc_data = np.load(mc_path)
#y_train, y_test = train_test_split(mc_data, test_size=0.2)
x_train, x_test, y_train, y_test = train_test_split(myarray_data, mc_data, test_size=0.2)

print(len(x_train), 'train examples')
print(len(x_test), 'test examples')
print(len(y_train), 'train examples')
print(len(y_test), 'test examples')
# Out:
# 1310 train examples
# 328 test examples
# 1310 train examples
# 328 test examples

# %%
x_train
# Out:
# array([[  33.46912452,    7.00701799,   72.71001914, ...,    0.        ,
#            0.        ,    0.        ],
#        [   5.1       ,   10.90707357,   54.53746463, ...,    0.        ,
#            0.        ,    0.        ],
#        [   7.77696327,   17.41389274,    8.26607367, ...,    0.        ,
#            0.        ,    0.        ],
#        ...,
#        [ 460.07340602,    6.79098534, 1000.        , ...,    0.        ,
#            0.        ,    0.        ],
#        [  86.54655979,    6.46358213,   34.12058909, ...,    0.        ,
#            0.        ,    0.        ],
#        [  37.85561002,   16.51989695,   75.76483684, ...,    0.        ,
#            0.        ,    0.        ]])

# %%
myarray_data.shape
# Out:
# (1638, 155)

# %%
x_train.shape
# Out:
# (1310, 155)

# %%
# Add a channels dimension
#x_train = x_train[..., tf.newaxis]
#x_test = x_test[..., tf.newaxis]

# %%
x_train.shape
# Out:
# (1310, 155)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ## Set my model

# %%
def build_model():
    model = tf.keras.Sequential([
        layers.Dense(10, activation='relu', input_shape=[155]),
        layers.Dense(5),
        layers.Dense(1)
    ])

    #optimizer = tf.keras.optimizers.RMSprop(0.001)
    optimizer = tf.keras.optimizers.Adam()

    model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
    return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1560
# _________________________________________________________________
# dense_13 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 1,621
# Trainable params: 1,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = x_train[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[ -86.270035],
#        [ -14.676371],
#        [   6.004719],
#        [-175.44476 ],
#        [-125.7872  ],
#        [ -54.66883 ],
#        [-335.69275 ],
#        [ -71.67061 ],
#        [ -51.39063 ],
#        [ -69.301346]], dtype=float32)

# %%
# エポックが終わるごとにドットを一つ出力することで進捗を表示
class PrintDot(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

EPOCHS = 150

history = model.fit(
    x_train, y_train,
    epochs=EPOCHS, validation_split = 0.2, verbose=0,
    callbacks=[PrintDot()]
)
# Out:
# ....................................................................................................
# ..................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#            loss       mae         mse    val_loss    val_mae     val_mse  \
# 145  124.809532  8.522678  124.809532  399.994965  14.066391  399.994965
# 146  123.775940  8.386511  123.775940  392.708618  13.740114  392.708618
# 147  121.856285  8.266236  121.856285  374.083771  13.286096  374.083771
# 148  121.505768  8.286680  121.505775  383.808319  13.451279  383.808319
# 149  119.063438  8.222102  119.063438  378.487335  13.215863  378.487335
#
#      epoch
# 145    145
# 146    146
# 147    147
# 148    148
# 149    149

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [mc]')
    plt.plot(hist['epoch'], hist['mae'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'], label = 'Val Error')
    plt.ylim([0,30])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$mc^2$]')
    plt.plot(hist['epoch'], hist['mse'], label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'], label = 'Val Error')
    plt.ylim([0,400])
    plt.legend()
    plt.show()


plot_history(history)

# %%
test_predictions = model.predict(x_test).flatten()

plt.figure(figsize=(6,6))
plt.scatter(y_test, test_predictions)
plt.xlabel('True Values [mc]')
plt.ylabel('Predictions [mc]')
plt.axis('equal')
plt.axis('square')
plt.xlim([-1,100])
plt.ylim([-1,100])
_ = plt.plot([-100, 100], [-100, 100])

# %%
np.corrcoef(y_test, test_predictions)
# Out:
# array([[1.        , 0.45969079],
#        [0.45969079, 1.        ]])
